# %% [markdown]
# DECISION TREE CLASSIFIER WITH FAMOUS 'Iris Dataset'
# @GRIP THE SPARKS FOUNDATION
# THIS NOTEBOOK PREDICT THE SPECIES OF A FLOWER FROM IT'S SEPAL LENGTH,
# SEPAL WIDTH, PETAL LENGTH AND PETAL WIDTH

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
df.drop('Id',inplace=True,axis=1)

# %%
df['Species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %%
df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['Species']=df['Species'].apply(lambda x:x.split('-')[1])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df.drop('Species',axis=1)/100,df['Species'],test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
sns.scatterplot(x=df['SepalLengthCm']/100,y=df['SepalWidthCm']/100,hue=df['Species'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(x=df['PetalLengthCm']/100,y=df['PetalWidthCm']/100,hue=df['Species'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>
